# %% [markdown]
# # side model labels

# %%
from jesse import research, helpers
from offline.labeling.labeling import (
    TripleBarrierLabeler,
    expand_labels,
    return_of_label,
)

_, trading_15m = research.get_candles(
    "Binance Perpetual Futures",
    "BTC-USDT",
    "15m",
    helpers.date_to_timestamp("2020-06-01"),
    helpers.date_to_timestamp("2025-01-31"),
    warmup_candles_num=0,
    caching=False,
    is_for_jesse=False,
)

# %%
def get_side_label(candles, num_hours, target_ret, pt_sl, last_ret, verbose=False):
    labeler = TripleBarrierLabeler(candles, num_hours=num_hours, verbose=verbose)
    side_labels = labeler.side_labels(pt=pt_sl, sl=pt_sl, target_ret=target_ret)
    candle_df = expand_labels(side_labels, candles, fill=0)
    ret = return_of_label(candle_df)
    label_counts = candle_df["bin"].value_counts().sort_index().to_numpy()
    print(
        f"{num_hours = } {target_ret = :.6f} {pt_sl = :.2f} -> {label_counts = } {ret = :.6f}({ret - last_ret :.6f})"
    )
    return ret

# %%
LAST_RET = [0]
target_ret = 0.0005
pt_sl = 1
for i in range(1, 24):
    num_hours = i
    ret = get_side_label(
        trading_15m, num_hours, target_ret, pt_sl, LAST_RET[-1], verbose=False
    )
    LAST_RET.append(ret)
# Out:
# num_hours = 1 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([  3060, 157575,   3045]) ret = 10.890498702089424(10.890498702089424)
# num_hours = 2 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([  7744, 148371,   7565]) ret = 15.220573156387653(4.330074454298229)
# num_hours = 3 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([ 12203, 139242,  12235]) ret = 17.608893442334505(2.388320285946852)
# num_hours = 4 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([ 16317, 130772,  16591]) ret = 18.612005885584026(1.0031124432495204)
# num_hours = 5 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([ 20108, 122999,  20573]) ret = 19.38104419219815(0.7690383066141244)
# num_hours = 6 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([ 23448, 115928,  24304]) ret = 19.787467680918336(0.4064234887201863)
# num_hours = 7 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([ 26320, 109658,  27702]) ret = 19.76637924704489(-0.021088433873448054)
# num_hours = 8 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([ 28942, 104056,  30682]) ret = 19.522973453209026(-0.24340579383586203)
# num_hours = 9 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([31372, 98881, 33427]) ret = 19.26824493769711(-0.25472851551191766)
# num_hours = 10 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([33674, 94035, 35971]) ret = 19.090809095532176(-0.17743584216493247)
# num_hours = 11 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([35756, 89565, 38359]) ret = 18.671787717273116(-0.4190213782590604)
# num_hours = 12 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([37695, 85504, 40481]) ret = 18.22097464675519(-0.4508130705179241)
# num_hours = 13 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([39499, 81696, 42485]) ret = 17.819547517624567(-0.4014271291306244)
# num_hours = 14 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([41105, 78315, 44260]) ret = 17.426101979183628(-0.39344553844093966)
# num_hours = 15 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([42603, 75187, 45890]) ret = 17.05326754017608(-0.37283443900754776)
# num_hours = 16 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([44019, 72291, 47370]) ret = 16.493208436424013(-0.5600591037520672)
# num_hours = 17 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([45308, 69592, 48780]) ret = 16.220391844934372(-0.2728165914896401)
# num_hours = 18 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([46516, 67042, 50122]) ret = 15.913039203296902(-0.3073526416374701)
# num_hours = 19 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([47661, 64676, 51343]) ret = 15.546881878949707(-0.3661573243471956)
# num_hours = 20 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([48783, 62371, 52526]) ret = 15.277807278530856(-0.26907460041885045)
# num_hours = 21 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([49840, 60215, 53625]) ret = 14.83611198913054(-0.4416952894003163)
# num_hours = 22 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([50770, 58285, 54625]) ret = 14.564778663990865(-0.27133332513967545)
# num_hours = 23 target_ret = 0.0005 pt_sl = 1 -> label_counts = array([51639, 56532, 55509]) ret = 14.20063603973768(-0.36414262425318533)

# %%
import numpy as np

LAST_RET = [0]
num_hours = 6
target_ret = 0.0005
for i in np.arange(0.1, 3.0, 0.1):
    pt_sl = i
    ret = get_side_label(
        trading_15m, num_hours, target_ret, pt_sl, LAST_RET[-1], verbose=False
    )
    LAST_RET.append(ret)
# Out:
# num_hours = 6 target_ret = 0.000500 pt_sl = 0.10 -> label_counts = array([72511, 17787, 73382]) ret = 8.308698(8.308698)
# num_hours = 6 target_ret = 0.000500 pt_sl = 0.20 -> label_counts = array([69359, 23109, 71212]) ret = 10.598816(2.290118)
# num_hours = 6 target_ret = 0.000500 pt_sl = 0.30 -> label_counts = array([63283, 35185, 65212]) ret = 15.776169(5.177352)
# num_hours = 6 target_ret = 0.000500 pt_sl = 0.40 -> label_counts = array([56040, 50110, 57530]) ret = 19.488769(3.712601)
# num_hours = 6 target_ret = 0.000500 pt_sl = 0.50 -> label_counts = array([48440, 65182, 50058]) ret = 22.229818(2.741048)
# num_hours = 6 target_ret = 0.000500 pt_sl = 0.60 -> label_counts = array([41751, 78614, 43315]) ret = 23.038697(0.808879)
# num_hours = 6 target_ret = 0.000500 pt_sl = 0.70 -> label_counts = array([35922, 90264, 37494]) ret = 23.148692(0.109996)
# num_hours = 6 target_ret = 0.000500 pt_sl = 0.80 -> label_counts = array([ 31014, 100322,  32344]) ret = 22.499664(-0.649028)
# num_hours = 6 target_ret = 0.000500 pt_sl = 0.90 -> label_counts = array([ 26942, 108789,  27949]) ret = 21.037843(-1.461821)
# num_hours = 6 target_ret = 0.000500 pt_sl = 1.00 -> label_counts = array([ 23448, 115928,  24304]) ret = 19.787468(-1.250376)
# num_hours = 6 target_ret = 0.000500 pt_sl = 1.10 -> label_counts = array([ 20497, 122175,  21008]) ret = 18.151065(-1.636402)
# num_hours = 6 target_ret = 0.000500 pt_sl = 1.20 -> label_counts = array([ 17966, 127308,  18406]) ret = 16.613928(-1.537137)
# num_hours = 6 target_ret = 0.000500 pt_sl = 1.30 -> label_counts = array([ 15804, 131752,  16124]) ret = 14.954201(-1.659727)
# num_hours = 6 target_ret = 0.000500 pt_sl = 1.40 -> label_counts = array([ 13993, 135546,  14141]) ret = 13.727559(-1.226642)
# num_hours = 6 target_ret = 0.000500 pt_sl = 1.50 -> label_counts = array([ 12511, 138723,  12446]) ret = 12.292292(-1.435266)
# num_hours = 6 target_ret = 0.000500 pt_sl = 1.60 -> label_counts = array([ 11220, 141422,  11038]) ret = 11.208593(-1.083699)
# num_hours = 6 target_ret = 0.000500 pt_sl = 1.70 -> label_counts = array([ 10080, 143706,   9894]) ret = 10.301286(-0.907307)
# num_hours = 6 target_ret = 0.000500 pt_sl = 1.80 -> label_counts = array([  9033, 145827,   8820]) ret = 9.392063(-0.909223)
# num_hours = 6 target_ret = 0.000500 pt_sl = 1.90 -> label_counts = array([  8104, 147625,   7951]) ret = 8.702085(-0.689978)
# num_hours = 6 target_ret = 0.000500 pt_sl = 2.00 -> label_counts = array([  7310, 149233,   7137]) ret = 7.930030(-0.772054)
# num_hours = 6 target_ret = 0.000500 pt_sl = 2.10 -> label_counts = array([  6628, 150636,   6416]) ret = 7.309971(-0.620059)
# num_hours = 6 target_ret = 0.000500 pt_sl = 2.20 -> label_counts = array([  5937, 151955,   5788]) ret = 6.610811(-0.699160)
# num_hours = 6 target_ret = 0.000500 pt_sl = 2.30 -> label_counts = array([  5332, 153115,   5233]) ret = 6.120552(-0.490260)
# num_hours = 6 target_ret = 0.000500 pt_sl = 2.40 -> label_counts = array([  4828, 154137,   4715]) ret = 5.515934(-0.604618)
# num_hours = 6 target_ret = 0.000500 pt_sl = 2.50 -> label_counts = array([  4375, 155048,   4257]) ret = 5.071342(-0.444591)
# num_hours = 6 target_ret = 0.000500 pt_sl = 2.60 -> label_counts = array([  3980, 155842,   3858]) ret = 4.645210(-0.426132)
# num_hours = 6 target_ret = 0.000500 pt_sl = 2.70 -> label_counts = array([  3651, 156508,   3521]) ret = 4.284374(-0.360836)
# num_hours = 6 target_ret = 0.000500 pt_sl = 2.80 -> label_counts = array([  3355, 157132,   3193]) ret = 3.811536(-0.472838)
# num_hours = 6 target_ret = 0.000500 pt_sl = 2.90 -> label_counts = array([  3044, 157681,   2955]) ret = 3.493363(-0.318173)

# %%
import numpy as np

LAST_RET = [0]
num_hours = 6
target_ret = 0.001
for i in np.arange(0.6, 0.8, 0.01):
    pt_sl = i
    ret = get_side_label(
        trading_15m, num_hours, target_ret, pt_sl, LAST_RET[-1], verbose=False
    )
    LAST_RET.append(ret)
# Out:
# num_hours = 6 target_ret = 0.001000 pt_sl = 0.60 -> label_counts = array([41751, 78614, 43315]) ret = 23.038697(23.038697)
# num_hours = 6 target_ret = 0.001000 pt_sl = 0.61 -> label_counts = array([41140, 79800, 42740]) ret = 23.078259(0.039562)
# num_hours = 6 target_ret = 0.001000 pt_sl = 0.62 -> label_counts = array([40529, 81030, 42121]) ret = 23.092490(0.014231)
# num_hours = 6 target_ret = 0.001000 pt_sl = 0.63 -> label_counts = array([39937, 82207, 41536]) ret = 23.076741(-0.015749)
# num_hours = 6 target_ret = 0.001000 pt_sl = 0.64 -> label_counts = array([39299, 83481, 40900]) ret = 23.133186(0.056446)
# num_hours = 6 target_ret = 0.001000 pt_sl = 0.65 -> label_counts = array([38721, 84669, 40290]) ret = 23.215335(0.082148)
# num_hours = 6 target_ret = 0.001000 pt_sl = 0.66 -> label_counts = array([38148, 85845, 39687]) ret = 23.220916(0.005581)
# num_hours = 6 target_ret = 0.001000 pt_sl = 0.67 -> label_counts = array([37582, 87013, 39085]) ret = 23.308409(0.087492)
# num_hours = 6 target_ret = 0.001000 pt_sl = 0.68 -> label_counts = array([37035, 88138, 38507]) ret = 23.280569(-0.027840)
# num_hours = 6 target_ret = 0.001000 pt_sl = 0.69 -> label_counts = array([36481, 89237, 37962]) ret = 23.209805(-0.070764)
# num_hours = 6 target_ret = 0.001000 pt_sl = 0.70 -> label_counts = array([35922, 90264, 37494]) ret = 23.148692(-0.061113)
# num_hours = 6 target_ret = 0.001000 pt_sl = 0.71 -> label_counts = array([35410, 91341, 36929]) ret = 23.156810(0.008118)
# num_hours = 6 target_ret = 0.001000 pt_sl = 0.72 -> label_counts = array([34891, 92380, 36409]) ret = 23.219873(0.063063)
# num_hours = 6 target_ret = 0.001000 pt_sl = 0.73 -> label_counts = array([34392, 93406, 35882]) ret = 23.178180(-0.041693)
# num_hours = 6 target_ret = 0.001000 pt_sl = 0.74 -> label_counts = array([33919, 94426, 35335]) ret = 23.036893(-0.141287)
# num_hours = 6 target_ret = 0.001000 pt_sl = 0.75 -> label_counts = array([33418, 95509, 34753]) ret = 22.943805(-0.093088)
# num_hours = 6 target_ret = 0.001000 pt_sl = 0.76 -> label_counts = array([32912, 96503, 34265]) ret = 22.945750(0.001945)
# num_hours = 6 target_ret = 0.001000 pt_sl = 0.77 -> label_counts = array([32392, 97513, 33775]) ret = 22.802392(-0.143358)
# num_hours = 6 target_ret = 0.001000 pt_sl = 0.78 -> label_counts = array([31900, 98488, 33292]) ret = 22.663363(-0.139030)
# num_hours = 6 target_ret = 0.001000 pt_sl = 0.79 -> label_counts = array([31463, 99427, 32790]) ret = 22.625514(-0.037849)
# num_hours = 6 target_ret = 0.001000 pt_sl = 0.80 -> label_counts = array([ 31014, 100322,  32344]) ret = 22.499664(-0.125850)

# %%
import numpy as np

LAST_RET = [0]
num_hours = 6
pt_sl = 0.72
for i in np.arange(0.0005, 0.015, 0.0005):
    target_ret = i
    ret = get_side_label(
        trading_15m, num_hours, target_ret, pt_sl, LAST_RET[-1], verbose=False
    )
    LAST_RET.append(ret)
# Out:
# num_hours = 6 target_ret = 0.000500 pt_sl = 0.72 -> label_counts = array([34891, 92380, 36409]) ret = 23.219873(23.219873)
# num_hours = 6 target_ret = 0.001000 pt_sl = 0.72 -> label_counts = array([34891, 92380, 36409]) ret = 23.219873(0.000000)
# num_hours = 6 target_ret = 0.001500 pt_sl = 0.72 -> label_counts = array([34887, 92384, 36409]) ret = 23.219970(0.000097)
# num_hours = 6 target_ret = 0.002000 pt_sl = 0.72 -> label_counts = array([34812, 92498, 36370]) ret = 23.218044(-0.001927)
# num_hours = 6 target_ret = 0.002500 pt_sl = 0.72 -> label_counts = array([34671, 92773, 36236]) ret = 23.209331(-0.008713)
# num_hours = 6 target_ret = 0.003000 pt_sl = 0.72 -> label_counts = array([34481, 93214, 35985]) ret = 23.191959(-0.017372)
# num_hours = 6 target_ret = 0.003500 pt_sl = 0.72 -> label_counts = array([34252, 93717, 35711]) ret = 23.175700(-0.016259)
# num_hours = 6 target_ret = 0.004000 pt_sl = 0.72 -> label_counts = array([33973, 94320, 35387]) ret = 23.125637(-0.050064)
# num_hours = 6 target_ret = 0.004500 pt_sl = 0.72 -> label_counts = array([33550, 95127, 35003]) ret = 23.088197(-0.037440)
# num_hours = 6 target_ret = 0.005000 pt_sl = 0.72 -> label_counts = array([33002, 96213, 34465]) ret = 23.029434(-0.058762)
# num_hours = 6 target_ret = 0.005500 pt_sl = 0.72 -> label_counts = array([32278, 97687, 33715]) ret = 22.936152(-0.093283)
# num_hours = 6 target_ret = 0.006000 pt_sl = 0.72 -> label_counts = array([31462, 99263, 32955]) ret = 22.803813(-0.132338)
# num_hours = 6 target_ret = 0.006500 pt_sl = 0.72 -> label_counts = array([ 30746, 100780,  32154]) ret = 22.666203(-0.137610)
# num_hours = 6 target_ret = 0.007000 pt_sl = 0.72 -> label_counts = array([ 29933, 102431,  31316]) ret = 22.448764(-0.217439)
# num_hours = 6 target_ret = 0.007500 pt_sl = 0.72 -> label_counts = array([ 29042, 104347,  30291]) ret = 22.113352(-0.335412)
# num_hours = 6 target_ret = 0.008000 pt_sl = 0.72 -> label_counts = array([ 28106, 106426,  29148]) ret = 21.786509(-0.326843)
# num_hours = 6 target_ret = 0.008500 pt_sl = 0.72 -> label_counts = array([ 27149, 108565,  27966]) ret = 21.391063(-0.395446)
# num_hours = 6 target_ret = 0.009000 pt_sl = 0.72 -> label_counts = array([ 26066, 110717,  26897]) ret = 20.977111(-0.413952)
# num_hours = 6 target_ret = 0.009500 pt_sl = 0.72 -> label_counts = array([ 25120, 112665,  25895]) ret = 20.635972(-0.341139)
# num_hours = 6 target_ret = 0.010000 pt_sl = 0.72 -> label_counts = array([ 24182, 114693,  24805]) ret = 20.197285(-0.438687)
# num_hours = 6 target_ret = 0.010500 pt_sl = 0.72 -> label_counts = array([ 23169, 116798,  23713]) ret = 19.677072(-0.520213)
# num_hours = 6 target_ret = 0.011000 pt_sl = 0.72 -> label_counts = array([ 22201, 118801,  22678]) ret = 19.205398(-0.471675)
# num_hours = 6 target_ret = 0.011500 pt_sl = 0.72 -> label_counts = array([ 21217, 120937,  21526]) ret = 18.708816(-0.496582)
# num_hours = 6 target_ret = 0.012000 pt_sl = 0.72 -> label_counts = array([ 20260, 122979,  20441]) ret = 18.186827(-0.521988)
# num_hours = 6 target_ret = 0.012500 pt_sl = 0.72 -> label_counts = array([ 19319, 124923,  19438]) ret = 17.538260(-0.648568)
# num_hours = 6 target_ret = 0.013000 pt_sl = 0.72 -> label_counts = array([ 18268, 126944,  18468]) ret = 16.980496(-0.557764)
# num_hours = 6 target_ret = 0.013500 pt_sl = 0.72 -> label_counts = array([ 17309, 128765,  17606]) ret = 16.388717(-0.591779)
# num_hours = 6 target_ret = 0.014000 pt_sl = 0.72 -> label_counts = array([ 16436, 130413,  16831]) ret = 15.820855(-0.567862)
# num_hours = 6 target_ret = 0.014500 pt_sl = 0.72 -> label_counts = array([ 15672, 131926,  16082]) ret = 15.258073(-0.562782)
