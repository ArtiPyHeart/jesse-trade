# %%
from jesse import helpers, research

_, trading_1m = research.get_candles(
    "Binance Perpetual Futures",
    "BTC-USDT",
    "1m",
    start_date_timestamp=helpers.date_to_timestamp("2024-01-01"),
    finish_date_timestamp=helpers.date_to_timestamp("2024-01-31"),
)
_, trading_3m = research.get_candles(
    "Binance Perpetual Futures",
    "BTC-USDT",
    "3m",
    start_date_timestamp=helpers.date_to_timestamp("2024-01-01"),
    finish_date_timestamp=helpers.date_to_timestamp("2024-01-31"),
)
_, trading_15m = research.get_candles(
    "Binance Perpetual Futures",
    "BTC-USDT",
    "15m",
    start_date_timestamp=helpers.date_to_timestamp("2024-01-01"),
    finish_date_timestamp=helpers.date_to_timestamp("2024-01-31"),
)
