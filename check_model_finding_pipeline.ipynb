# %%
import pandas as pd

df = pd.read_csv("model_search_results.csv")

# %%
df[df['model_type'] == 'classifier'].sort_values(['best_score'], ascending=False)
# Out:
#     log_return_lag  pred_next  model_type  best_score  feature_count  \
# 19               7          1  classifier    0.946108           3855
# 13               6          1  classifier    0.944998           3873
# 21               7          2  classifier    0.939904           4055
# 23               7          3  classifier    0.939111           4196
# 15               6          2  classifier    0.937905           4085
# 7                5          1  classifier    0.936203           3950
# 17               6          3  classifier    0.931701           4313
# 11               5          3  classifier    0.930833           4275
# 9                5          2  classifier    0.928777           1623
# 1                4          1  classifier    0.926340           3659
# 3                4          2  classifier    0.910941           3980
# 5                4          3  classifier    0.905196           4093
#
#               timestamp     status  duration_seconds  \
# 19  2025-11-26 08:33:02  completed      10481.907957
# 13  2025-11-25 09:36:22  completed      10885.193470
# 21  2025-11-26 16:45:32  completed      19865.845688
# 23  2025-11-26 23:42:48  completed      14106.769767
# 15  2025-11-25 17:09:43  completed      14040.342036
# 7   2025-11-24 12:58:00  completed      11246.931559
# 17  2025-11-26 02:00:22  completed      18206.616384
# 11  2025-11-25 03:44:39  completed      15328.147648
# 9   2025-11-24 19:06:15  completed       8509.783126
# 1   2025-11-23 06:25:01  completed       9781.328661
# 3   2025-11-23 19:17:26  completed      13419.081277
# 5   2025-11-24 07:13:07  completed      29275.141846
#
#                                           best_params  \
# 19  {"objective": "binary", "num_threads": -1, "ve...
# 13  {"objective": "binary", "num_threads": -1, "ve...
# 21  {"objective": "binary", "num_threads": -1, "ve...
# 23  {"objective": "binary", "num_threads": -1, "ve...
# 15  {"objective": "binary", "num_threads": -1, "ve...
# 7   {"objective": "binary", "num_threads": -1, "ve...
# 17  {"objective": "binary", "num_threads": -1, "ve...
# 11  {"objective": "binary", "num_threads": -1, "ve...
# 9   {"objective": "binary", "num_threads": -1, "ve...
# 1   {"objective": "binary", "num_threads": -1, "ve...
# 3   {"objective": "binary", "num_threads": -1, "ve...
# 5   {"objective": "binary", "num_threads": -1, "ve...
#
#                                     selected_features
# 19  ["reactivity", "trendflex", "williams_r", "aro...
# 13  ["williams_r", "cmma", "fisher", "evenbetter_s...
# 21  ["williams_r", "cmma", "reactivity", "trendfle...
# 23  ["williams_r", "cmma", "cmma_lag1", "fisher", ...
# 15  ["cmma", "williams_r", "fisher", "cmma_lag1", ...
# 7   ["cmma", "williams_r", "evenbetter_sinewave_sh...
# 17  ["cmma", "williams_r", "stc_dt", "cmma_lag1", ...
# 11  ["cmma", "williams_r", "stc_dt", "williams_r_n...
# 9   ["cmma", "williams_r", "stc_dt", "cmma_lag1", ...
# 1   ["cmma", "williams_r", "stc_dt", "evenbetter_s...
# 3   ["cmma", "williams_r", "fisher_dt", "evenbette...
# 5   ["cmma", "williams_r", "williams_r_norm20", "f...

# %%
df[df['model_type'] == 'regressor'].sort_values(['best_score'], ascending=False)
# Out:
#     log_return_lag  pred_next model_type  best_score  feature_count  \
# 12               6          1  regressor    0.930831           3363
# 18               7          1  regressor    0.930584           3405
# 6                5          1  regressor    0.919896           3450
# 20               7          2  regressor    0.910209           3803
# 0                4          1  regressor    0.908046           3036
# 22               7          3  regressor    0.907510           3997
# 14               6          2  regressor    0.901118           3786
# 16               6          3  regressor    0.889377           4145
# 8                5          2  regressor    0.885996           3817
# 10               5          3  regressor    0.867556           3954
# 2                4          2  regressor    0.863033           3527
# 4                4          3  regressor    0.834743           3809
#
#               timestamp     status  duration_seconds  \
# 12  2025-11-25 06:34:56  completed      10216.515245
# 18  2025-11-26 05:38:19  completed      13074.928688
# 6   2025-11-24 09:50:32  completed       9443.856529
# 20  2025-11-26 11:14:25  completed       9682.431705
# 0   2025-11-23 03:41:59  completed      15507.161724
# 22  2025-11-26 19:47:41  completed      10927.675336
# 14  2025-11-25 13:15:42  completed      13159.138933
# 16  2025-11-25 20:56:55  completed      13630.239872
# 8   2025-11-24 16:44:24  completed      13582.786205
# 10  2025-11-24 23:29:09  completed      15774.058745
# 2   2025-11-23 15:33:46  completed      16834.779150
# 4   2025-11-23 23:05:11  completed      13663.899365
#
#                                           best_params  \
# 12  {"objective": "regression", "num_threads": -1,...
# 18  {"objective": "regression", "num_threads": -1,...
# 6   {"objective": "regression", "num_threads": -1,...
# 20  {"objective": "regression", "num_threads": -1,...
# 0   {"objective": "regression", "num_threads": -1,...
# 22  {"objective": "regression", "num_threads": -1,...
# 14  {"objective": "regression", "num_threads": -1,...
# 16  {"objective": "regression", "num_threads": -1,...
# 8   {"objective": "regression", "num_threads": -1,...
# 10  {"objective": "regression", "num_threads": -1,...
# 2   {"objective": "regression", "num_threads": -1,...
# 4   {"objective": "regression", "num_threads": -1,...
#
#                                     selected_features
# 12  ["williams_r", "cmma", "fisher", "aroon_diff",...
# 18  ["reactivity", "trendflex", "aroon_diff", "wil...
# 6   ["cmma", "williams_r", "fisher", "evenbetter_s...
# 20  ["williams_r", "reactivity", "cmma", "trendfle...
# 0   ["cmma", "williams_r", "stc_dt", "cmma_lag1", ...
# 22  ["williams_r", "cmma", "cmma_lag1", "trendflex...
# 14  ["cmma", "williams_r", "fisher", "cmma_lag1", ...
# 16  ["cmma", "williams_r", "stc_dt", "cmma_lag1", ...
# 8   ["cmma", "williams_r", "stc_dt", "cmma_lag1", ...
# 10  ["cmma", "williams_r", "stc_dt", "williams_r_n...
# 2   ["cmma", "williams_r", "stc_dt", "evenbetter_s...
# 4   ["cmma", "williams_r", "fisher_dt", "williams_...
