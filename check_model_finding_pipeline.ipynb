# %%
import pandas as pd

df = pd.read_csv("model_search_results.csv")

# %%
df[df['model_type'] == 'classifier'].sort_values(['best_score'], ascending=False)
# Out:
#     log_return_lag  pred_next  model_type  best_score  feature_count  \
# 19               7          1  classifier    0.903522           3391
# 13               6          1  classifier    0.889889           3286
# 21               7          2  classifier    0.882710           3544
# 23               7          3  classifier    0.878544           3626
# 15               6          2  classifier    0.873453           3458
# 7                5          1  classifier    0.863980           3066
# 17               6          3  classifier    0.862445           1067
# 11               5          3  classifier    0.862120           1340
# 9                5          2  classifier    0.841266           3296
# 1                4          1  classifier    0.828200           2704
# 5                4          3  classifier    0.820799           1847
# 3                4          2  classifier    0.804211           1009
#
#               timestamp     status  duration_seconds  \
# 19  2025-11-08 01:32:34  completed      10001.804287
# 13  2025-11-07 08:19:57  completed       9072.697730
# 21  2025-11-08 07:06:43  completed       9493.820877
# 23  2025-11-08 12:44:07  completed      10717.265167
# 15  2025-11-07 14:12:18  completed      10787.726010
# 7   2025-11-06 10:59:57  completed      10773.919717
# 17  2025-11-07 20:09:31  completed       9895.413057
# 11  2025-11-07 03:08:27  completed      11005.723104
# 9   2025-11-06 16:32:02  completed       9996.305501
# 1   2025-11-05 18:23:00  completed       8893.497244
# 5   2025-11-06 05:22:46  completed       9295.566796
# 3   2025-11-06 00:15:22  completed       9753.105789
#
#                                           best_params  \
# 19  {"objective": "binary", "num_threads": -1, "ve...
# 13  {"objective": "binary", "num_threads": -1, "ve...
# 21  {"objective": "binary", "num_threads": -1, "ve...
# 23  {"objective": "binary", "num_threads": -1, "ve...
# 15  {"objective": "binary", "num_threads": -1, "ve...
# 7   {"objective": "binary", "num_threads": -1, "ve...
# 17  {"objective": "binary", "num_threads": -1, "ve...
# 11  {"objective": "binary", "num_threads": -1, "ve...
# 9   {"objective": "binary", "num_threads": -1, "ve...
# 1   {"objective": "binary", "num_threads": -1, "ve...
# 5   {"objective": "binary", "num_threads": -1, "ve...
# 3   {"objective": "binary", "num_threads": -1, "ve...
#
#                                     selected_features
# 19  ["cmma", "williams_r", "evenbetter_sinewave_sh...
# 13  ["williams_r", "cmma", "evenbetter_sinewave_sh...
# 21  ["williams_r", "cmma", "fisher_dt", "lg_ssm_3"...
# 23  ["williams_r", "lg_ssm_3", "cmma", "fisher_dt"...
# 15  ["williams_r", "lg_ssm_3", "cmma", "fisher_dt"...
# 7   ["williams_r", "lg_ssm_3", "cmma", "fisher_dt"...
# 17  ["williams_r", "cmma", "trendflex_dt", "fisher...
# 11  ["voss_0_dt", "williams_r", "williams_r_norm20...
# 9   ["williams_r", "cmma", "fisher_dt", "trendflex...
# 1   ["williams_r", "cmma", "frac_c_h3_diff", "fish...
# 5   ["bar_close_dt_zscore20", "williams_r_norm20",...
# 3   ["williams_r", "voss_0_dt", "williams_r_norm20...

# %%
df[df['model_type'] == 'regressor'].sort_values(['best_score'], ascending=False)
# Out:
#     log_return_lag  pred_next model_type  best_score  feature_count  \
# 18               7          1  regressor    0.774986           2732
# 12               6          1  regressor    0.738041           2625
# 20               7          2  regressor    0.706885           3104
# 22               7          3  regressor    0.685445           3475
# 14               6          2  regressor    0.670810           3192
# 6                5          1  regressor    0.661846           2582
# 10               5          3  regressor    0.617489           1149
# 16               6          3  regressor    0.613295           3294
# 8                5          2  regressor    0.594445           2888
# 0                4          1  regressor    0.579549           2056
# 2                4          2  regressor    0.529900           3280
# 4                4          3  regressor    0.517855           1746
#
#               timestamp     status  duration_seconds  \
# 18  2025-11-07 22:45:52  completed       9379.885044
# 12  2025-11-07 05:48:43  completed       9615.740202
# 20  2025-11-08 04:28:28  completed      10553.673327
# 22  2025-11-08 09:45:29  completed       9525.580330
# 14  2025-11-07 11:12:30  completed      10352.330594
# 6   2025-11-06 08:00:23  completed       9457.258342
# 10  2025-11-07 00:05:01  completed      21879.090566
# 16  2025-11-07 17:24:35  completed      11535.645303
# 8   2025-11-06 13:45:25  completed       9928.230376
# 0   2025-11-05 15:54:46  completed      20661.023384
# 2   2025-11-05 21:32:49  completed      11389.322931
# 4   2025-11-06 02:47:50  completed       9148.229820
#
#                                           best_params  \
# 18  {"objective": "regression", "num_threads": -1,...
# 12  {"objective": "regression", "num_threads": -1,...
# 20  {"objective": "regression", "num_threads": -1,...
# 22  {"objective": "regression", "num_threads": -1,...
# 14  {"objective": "regression", "num_threads": -1,...
# 6   {"objective": "regression", "num_threads": -1,...
# 10  {"objective": "regression", "num_threads": -1,...
# 16  {"objective": "regression", "num_threads": -1,...
# 8   {"objective": "regression", "num_threads": -1,...
# 0   {"objective": "regression", "num_threads": -1,...
# 2   {"objective": "regression", "num_threads": -1,...
# 4   {"objective": "regression", "num_threads": -1,...
#
#                                     selected_features
# 18  ["cmma", "williams_r", "evenbetter_sinewave_sh...
# 12  ["cmma", "williams_r", "lg_ssm_3", "evenbetter...
# 20  ["cmma", "williams_r", "lg_ssm_3", "fisher_dt"...
# 22  ["williams_r", "lg_ssm_3", "cmma", "trendflex_...
# 14  ["williams_r", "lg_ssm_3", "trendflex_dt", "cm...
# 6   ["williams_r", "lg_ssm_3", "cmma", "fisher_dt"...
# 10  ["voss_0_dt", "williams_r", "williams_r_norm20...
# 16  ["williams_r", "cmma", "trendflex_dt", "fisher...
# 8   ["williams_r", "cmma", "trendflex_dt", "fisher...
# 0   ["williams_r", "cmma", "trendflex_dt", "frac_c...
# 2   ["williams_r", "voss_0_dt", "williams_r_norm20...
# 4   ["bar_close_dt_zscore20", "williams_r_norm20",...
