# %%
import pandas as pd

df = pd.read_csv("model_search_results.csv")
df.head()
# Out:
#    log_return_lag  pred_next  model_type  best_score  feature_count  \
# 0               4          1   regressor    0.583000           2271
# 1               4          1  classifier    0.797792             14
# 2               4          2   regressor    0.515792           3112
# 3               4          2  classifier    0.774643             49
# 4               4          3   regressor    0.526980           4036
#
#              timestamp     status  duration_seconds  \
# 0  2025-09-28 23:04:06  completed      21442.279373
# 1  2025-09-29 01:06:15  completed       7328.387525
# 2  2025-09-29 05:12:56  completed      14800.998981
# 3  2025-09-29 07:39:11  completed       8775.591633
# 4  2025-09-29 18:30:15  completed      32703.909085
#
#                                          best_params  \
# 0  {"objective": "regression", "num_threads": -1,...
# 1  {"objective": "binary", "num_threads": -1, "ve...
# 2  {"objective": "regression", "num_threads": -1,...
# 3  {"objective": "binary", "num_threads": -1, "ve...
# 4  {"objective": "regression", "num_threads": -1,...
#
#                                    selected_features
# 0  ["williams_r", "cmma", "lg_ssm_3", "cwt_w32_0"...
# 1  ["cmma", "lg_ssm_3", "frac_c_h3_diff", "fisher...
# 2  ["williams_r", "cmma", "voss_0_dt", "bekker_pa...
# 3  ["williams_r", "cwt_w32_5", "cwt_w32_6", "bekk...
# 4  ["cmma_dt", "acc_swing_index_dt", "williams_r"...

# %%
df[df['model_type'] == 'classifier'].sort_values(['best_score'], ascending=True)
# Out:
#     log_return_lag  pred_next  model_type  best_score  feature_count  \
# 11               5          3  classifier    0.747376            124
# 9                5          2  classifier    0.764182             87
# 3                4          2  classifier    0.774643             49
# 1                4          1  classifier    0.797792             14
# 21               7          2  classifier    0.824589            152
# 29               8          3  classifier    0.829799            174
# 5                4          3  classifier    0.830471            513
# 17               6          3  classifier    0.854507           1012
# 7                5          1  classifier    0.862382           3079
# 15               6          2  classifier    0.869064           3344
# 13               6          1  classifier    0.885359           3162
# 19               7          1  classifier    0.890287           3366
# 23               7          3  classifier    0.891072           1138
# 27               8          2  classifier    0.891644           3620
# 35               9          3  classifier    0.891645           3588
# 37              10          1  classifier    0.896588            150
# 33               9          2  classifier    0.898031           3668
# 25               8          1  classifier    0.903412           3398
# 39              10          2  classifier    0.904575           1212
# 45              11          2  classifier    0.904901           1337
# 41              10          3  classifier    0.907654           3700
# 51              12          2  classifier    0.912127           3695
# 31               9          1  classifier    0.917982           3477
# 47              11          3  classifier    0.918131           1334
# 59              13          3  classifier    0.919475           3755
# 65              14          3  classifier    0.919726           3658
# 43              11          1  classifier    0.921329           3545
# 53              12          3  classifier    0.921714           3766
# 63              14          2  classifier    0.925115           3501
# 71              15          3  classifier    0.927246           1225
# 49              12          1  classifier    0.929701           3342
# 57              13          2  classifier    0.930448           3529
# 69              15          2  classifier    0.931862           3592
# 55              13          1  classifier    0.934282           3272
# 61              14          1  classifier    0.938931           3533
# 67              15          1  classifier    0.941100           3741
#
#               timestamp     status  duration_seconds  \
# 11  2025-10-01 00:17:10  completed       4237.470073
# 9   2025-09-30 22:01:38  completed       3705.754419
# 3   2025-09-29 07:39:11  completed       8775.591633
# 1   2025-09-29 01:06:15  completed       7328.387525
# 21  2025-10-01 11:58:32  completed       3885.600182
# 29  2025-10-01 20:49:54  completed       3346.258861
# 5   2025-09-29 20:39:49  completed       7774.109160
# 17  2025-10-01 07:22:27  completed       4035.793964
# 7   2025-09-30 19:40:21  completed      16982.994902
# 15  2025-10-01 05:05:48  completed       4614.227114
# 13  2025-10-01 02:41:31  completed       4198.254924
# 19  2025-10-01 09:35:52  completed       3972.132107
# 23  2025-10-01 14:18:50  completed       4177.058011
# 27  2025-10-01 18:43:44  completed       4237.879270
# 35  2025-10-03 08:13:14  completed       4915.014392
# 37  2025-10-03 10:17:46  completed       3503.320826
# 33  2025-10-03 05:39:06  completed       4228.851601
# 25  2025-10-01 16:27:29  completed       3915.086530
# 39  2025-10-03 12:32:06  completed       4066.219747
# 45  2025-10-03 19:21:18  completed       3708.344787
# 41  2025-10-03 14:57:30  completed       4241.433133
# 51  2025-10-04 02:07:20  completed       4275.324367
# 31  2025-10-03 03:20:23  completed       4181.547463
# 47  2025-10-03 21:36:58  completed       3978.286162
# 59  2025-10-07 02:46:44  completed       3969.943075
# 65  2025-10-07 09:29:22  completed       4275.226822
# 43  2025-10-03 17:04:42  completed       3923.140770
# 53  2025-10-04 04:24:14  completed       3835.072043
# 63  2025-10-07 07:12:47  completed       4242.303480
# 71  2025-10-07 16:20:38  completed       3870.406955
# 49  2025-10-03 23:49:58  completed       4045.914203
# 57  2025-10-07 00:38:14  completed       3965.205700
# 69  2025-10-07 14:11:18  completed       4195.021014
# 55  2025-10-06 22:20:57  completed       4298.754221
# 61  2025-10-07 05:00:30  completed       4093.588081
# 67  2025-10-07 11:51:43  completed       4376.627188
#
#                                           best_params  \
# 11  {"objective": "binary", "num_threads": -1, "ve...
# 9   {"objective": "binary", "num_threads": -1, "ve...
# 3   {"objective": "binary", "num_threads": -1, "ve...
# 1   {"objective": "binary", "num_threads": -1, "ve...
# 21  {"objective": "binary", "num_threads": -1, "ve...
# 29  {"objective": "binary", "num_threads": -1, "ve...
# 5   {"objective": "binary", "num_threads": -1, "ve...
# 17  {"objective": "binary", "num_threads": -1, "ve...
# 7   {"objective": "binary", "num_threads": -1, "ve...
# 15  {"objective": "binary", "num_threads": -1, "ve...
# 13  {"objective": "binary", "num_threads": -1, "ve...
# 19  {"objective": "binary", "num_threads": -1, "ve...
# 23  {"objective": "binary", "num_threads": -1, "ve...
# 27  {"objective": "binary", "num_threads": -1, "ve...
# 35  {"objective": "binary", "num_threads": -1, "ve...
# 37  {"objective": "binary", "num_threads": -1, "ve...
# 33  {"objective": "binary", "num_threads": -1, "ve...
# 25  {"objective": "binary", "num_threads": -1, "ve...
# 39  {"objective": "binary", "num_threads": -1, "ve...
# 45  {"objective": "binary", "num_threads": -1, "ve...
# 41  {"objective": "binary", "num_threads": -1, "ve...
# 51  {"objective": "binary", "num_threads": -1, "ve...
# 31  {"objective": "binary", "num_threads": -1, "ve...
# 47  {"objective": "binary", "num_threads": -1, "ve...
# 59  {"objective": "binary", "num_threads": -1, "ve...
# 65  {"objective": "binary", "num_threads": -1, "ve...
# 43  {"objective": "binary", "num_threads": -1, "ve...
# 53  {"objective": "binary", "num_threads": -1, "ve...
# 63  {"objective": "binary", "num_threads": -1, "ve...
# 71  {"objective": "binary", "num_threads": -1, "ve...
# 49  {"objective": "binary", "num_threads": -1, "ve...
# 57  {"objective": "binary", "num_threads": -1, "ve...
# 69  {"objective": "binary", "num_threads": -1, "ve...
# 55  {"objective": "binary", "num_threads": -1, "ve...
# 61  {"objective": "binary", "num_threads": -1, "ve...
# 67  {"objective": "binary", "num_threads": -1, "ve...
#
#                                     selected_features
# 11  ["williams_r", "cmma", "fisher_dt", "corwin_sc...
# 9   ["williams_r", "cmma", "frac_c_h3_diff", "cwt_...
# 3   ["williams_r", "cwt_w32_5", "cwt_w32_6", "bekk...
# 1   ["cmma", "lg_ssm_3", "frac_c_h3_diff", "fisher...
# 21  ["cmma", "fisher_dt", "williams_r", "evenbette...
# 29  ["cmma", "williams_r", "fisher_dt", "cwt_w32_1...
# 5   ["cmma_dt", "acc_swing_index_dt", "williams_r"...
# 17  ["williams_r", "cmma", "fisher_dt", "cwt_w32_0...
# 7   ["williams_r", "cmma", "trendflex_dt", "fisher...
# 15  ["williams_r", "cmma", "fisher_dt", "trendflex...
# 13  ["williams_r", "cmma", "evenbetter_sinewave_sh...
# 19  ["williams_r", "cmma", "evenbetter_sinewave_sh...
# 23  ["williams_r", "cmma", "trendflex_dt", "fisher...
# 27  ["williams_r", "cmma", "swamicharts_stochastic...
# 35  ["williams_r", "cmma", "adx_14_dt", "swamichar...
# 37  ["cmma", "fisher", "cwt_w32_1_lag5", "williams...
# 33  ["cmma", "williams_r", "cwt_w32_1_lag3", "swam...
# 25  ["cmma", "williams_r", "evenbetter_sinewave_sh...
# 39  ["cmma", "evenbetter_sinewave_short", "william...
# 45  ["cmma", "williams_r", "fisher", "evenbetter_s...
# 41  ["cmma", "williams_r", "swamicharts_stochastic...
# 51  ["cmma", "williams_r", "fisher", "fisher_lag1"...
# 31  ["cmma", "evenbetter_sinewave_short", "william...
# 47  ["cmma", "evenbetter_sinewave_short", "william...
# 59  ["cmma", "williams_r", "fisher", "evenbetter_s...
# 65  ["williams_r", "cmma", "trendflex", "fisher", ...
# 43  ["cmma", "fisher", "williams_r", "evenbetter_s...
# 53  ["cmma", "fisher", "williams_r", "evenbetter_s...
# 63  ["williams_r", "trendflex", "cmma", "reactivit...
# 71  ["williams_r", "trendflex", "reactivity", "cmm...
# 49  ["williams_r", "cmma", "aroon_diff", "evenbett...
# 57  ["williams_r", "cmma", "trendflex", "fisher", ...
# 69  ["williams_r", "trendflex", "reactivity", "cmm...
# 55  ["williams_r", "cmma", "trendflex", "reactivit...
# 61  ["williams_r", "reactivity", "trendflex", "cmm...
# 67  ["reactivity", "trendflex", "williams_r", "cmm...

# %%
df[df['model_type'] == 'regressor'].sort_values(['best_score'], ascending=False)
# Out:
#     log_return_lag  pred_next model_type  best_score  feature_count  \
# 66              15          1  regressor    0.870445           3288
# 60              14          1  regressor    0.853072           3110
# 48              12          1  regressor    0.852336           2877
# 54              13          1  regressor    0.852175           2776
# 68              15          2  regressor    0.846677           3279
# 42              11          1  regressor    0.821347           3060
# 62              14          2  regressor    0.819433           3195
# 56              13          2  regressor    0.813644           3249
# 36              10          1  regressor    0.811624           2944
# 44              11          2  regressor    0.789588           3367
# 30               9          1  regressor    0.786103           2837
# 46              11          3  regressor    0.782935           3463
# 50              12          2  regressor    0.780863           3444
# 32               9          2  regressor    0.774276           3308
# 18               7          1  regressor    0.769480           2662
# 52              12          3  regressor    0.767045           3513
# 70              15          3  regressor    0.763563           3300
# 40              10          3  regressor    0.762049           3469
# 58              13          3  regressor    0.760362           3594
# 38              10          2  regressor    0.753539           3395
# 24               8          1  regressor    0.752417           2764
# 64              14          3  regressor    0.731075           1184
# 12               6          1  regressor    0.721729           2598
# 28               8          3  regressor    0.697740           3302
# 26               8          2  regressor    0.692259           3122
# 20               7          2  regressor    0.688015           3146
# 22               7          3  regressor    0.673639           3199
# 34               9          3  regressor    0.672091           3389
# 14               6          2  regressor    0.669819           3007
# 6                5          1  regressor    0.661662           2563
# 16               6          3  regressor    0.583071           3183
# 0                4          1  regressor    0.583000           2271
# 10               5          3  regressor    0.555760           3276
# 8                5          2  regressor    0.554721           2916
# 4                4          3  regressor    0.526980           4036
# 2                4          2  regressor    0.515792           3112
#
#               timestamp     status  duration_seconds  \
# 66  2025-10-07 10:38:46  completed       4164.193071
# 60  2025-10-07 03:52:17  completed       3932.124690
# 48  2025-10-03 22:42:32  completed       3934.743242
# 54  2025-10-06 21:09:18  completed      15477.999676
# 68  2025-10-07 13:01:23  completed       4180.073884
# 42  2025-10-03 15:59:19  completed       3709.200304
# 62  2025-10-07 06:02:04  completed       3693.871656
# 56  2025-10-06 23:32:09  completed       4272.165489
# 36  2025-10-03 09:19:22  completed       3968.499604
# 44  2025-10-03 18:19:29  completed       4486.971522
# 30  2025-10-03 02:10:41  completed      14874.677443
# 46  2025-10-03 20:30:39  completed       4161.748906
# 50  2025-10-04 00:56:04  completed       3965.926057
# 32  2025-10-03 04:28:37  completed       4094.406636
# 18  2025-10-01 08:29:40  completed       4033.198979
# 52  2025-10-04 03:20:19  completed       4379.278812
# 70  2025-10-07 15:16:08  completed       3890.058554
# 40  2025-10-03 13:46:48  completed       4482.584716
# 58  2025-10-07 01:40:34  completed       3740.263147
# 38  2025-10-03 11:24:19  completed       3993.839940
# 24  2025-10-01 15:22:14  completed       3804.034902
# 64  2025-10-07 08:18:06  completed       3919.673902
# 12  2025-10-01 01:31:33  completed       4462.444728
# 28  2025-10-01 19:54:08  completed       4224.050011
# 26  2025-10-01 17:33:06  completed       3937.154021
# 20  2025-10-01 10:53:46  completed       4674.523293
# 22  2025-10-01 13:09:13  completed       4240.643229
# 34  2025-10-03 06:51:19  completed       4332.461920
# 14  2025-10-01 03:48:53  completed       4042.503822
# 6   2025-09-30 14:27:28  completed      16729.589063
# 16  2025-10-01 06:15:11  completed       4163.136201
# 0   2025-09-28 23:04:06  completed      21442.279373
# 10  2025-09-30 23:06:32  completed       3894.256952
# 8   2025-09-30 20:59:52  completed       4771.469510
# 4   2025-09-29 18:30:15  completed      32703.909085
# 2   2025-09-29 05:12:56  completed      14800.998981
#
#                                           best_params  \
# 66  {"objective": "regression", "num_threads": -1,...
# 60  {"objective": "regression", "num_threads": -1,...
# 48  {"objective": "regression", "num_threads": -1,...
# 54  {"objective": "regression", "num_threads": -1,...
# 68  {"objective": "regression", "num_threads": -1,...
# 42  {"objective": "regression", "num_threads": -1,...
# 62  {"objective": "regression", "num_threads": -1,...
# 56  {"objective": "regression", "num_threads": -1,...
# 36  {"objective": "regression", "num_threads": -1,...
# 44  {"objective": "regression", "num_threads": -1,...
# 30  {"objective": "regression", "num_threads": -1,...
# 46  {"objective": "regression", "num_threads": -1,...
# 50  {"objective": "regression", "num_threads": -1,...
# 32  {"objective": "regression", "num_threads": -1,...
# 18  {"objective": "regression", "num_threads": -1,...
# 52  {"objective": "regression", "num_threads": -1,...
# 70  {"objective": "regression", "num_threads": -1,...
# 40  {"objective": "regression", "num_threads": -1,...
# 58  {"objective": "regression", "num_threads": -1,...
# 38  {"objective": "regression", "num_threads": -1,...
# 24  {"objective": "regression", "num_threads": -1,...
# 64  {"objective": "regression", "num_threads": -1,...
# 12  {"objective": "regression", "num_threads": -1,...
# 28  {"objective": "regression", "num_threads": -1,...
# 26  {"objective": "regression", "num_threads": -1,...
# 20  {"objective": "regression", "num_threads": -1,...
# 22  {"objective": "regression", "num_threads": -1,...
# 34  {"objective": "regression", "num_threads": -1,...
# 14  {"objective": "regression", "num_threads": -1,...
# 6   {"objective": "regression", "num_threads": -1,...
# 16  {"objective": "regression", "num_threads": -1,...
# 0   {"objective": "regression", "num_threads": -1,...
# 10  {"objective": "regression", "num_threads": -1,...
# 8   {"objective": "regression", "num_threads": -1,...
# 4   {"objective": "regression", "num_threads": -1,...
# 2   {"objective": "regression", "num_threads": -1,...
#
#                                     selected_features
# 66  ["reactivity", "trendflex", "williams_r", "rea...
# 60  ["williams_r", "trendflex", "reactivity", "cmm...
# 48  ["williams_r", "cmma", "aroon_diff", "evenbett...
# 54  ["williams_r", "cmma", "aroon_diff", "reactivi...
# 68  ["williams_r", "trendflex", "reactivity", "cmm...
# 42  ["cmma", "williams_r", "fisher", "evenbetter_s...
# 62  ["williams_r", "reactivity", "cmma", "trendfle...
# 56  ["williams_r", "cmma", "fisher", "aroon_diff",...
# 36  ["cmma", "fisher", "williams_r", "cwt_w32_1_la...
# 44  ["cmma", "williams_r", "fisher", "cwt_w32_1_la...
# 30  ["cmma", "williams_r", "evenbetter_sinewave_sh...
# 46  ["cmma", "evenbetter_sinewave_short", "william...
# 50  ["cmma", "williams_r", "fisher", "evenbetter_s...
# 32  ["cmma", "williams_r", "cwt_w32_1_lag3", "swam...
# 18  ["williams_r", "cmma", "evenbetter_sinewave_sh...
# 52  ["cmma", "williams_r", "fisher", "evenbetter_s...
# 70  ["williams_r", "reactivity", "cmma", "trendfle...
# 40  ["cmma", "williams_r", "cwt_w32_1_lag3", "swam...
# 58  ["cmma", "fisher", "williams_r", "evenbetter_s...
# 38  ["cmma", "williams_r", "evenbetter_sinewave_sh...
# 24  ["cmma", "williams_r", "cwt_w32_1_lag3", "even...
# 64  ["williams_r", "cmma", "fisher", "aroon_diff",...
# 12  ["williams_r", "cmma", "evenbetter_sinewave_sh...
# 28  ["cmma", "williams_r", "fisher_dt", "trendflex...
# 26  ["cmma", "williams_r", "cwt_w32_1_lag2", "cwt_...
# 20  ["williams_r", "cmma", "trendflex_dt", "fisher...
# 22  ["cmma", "williams_r", "trendflex_dt", "cwt_w3...
# 34  ["cmma", "williams_r", "swamicharts_stochastic...
# 14  ["cmma", "williams_r", "fisher_dt", "trendflex...
# 6   ["williams_r", "cmma", "trendflex_dt", "fisher...
# 16  ["williams_r", "cmma", "trendflex_dt", "cwt_w3...
# 0   ["williams_r", "cmma", "lg_ssm_3", "cwt_w32_0"...
# 10  ["williams_r", "cmma", "voss_0_dt", "frac_c_l2...
# 8   ["williams_r", "cmma", "frac_c_h3_diff", "lg_s...
# 4   ["cmma_dt", "acc_swing_index_dt", "williams_r"...
# 2   ["williams_r", "cmma", "voss_0_dt", "bekker_pa...
