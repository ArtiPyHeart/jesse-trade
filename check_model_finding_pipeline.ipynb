# %%
import pandas as pd

df = pd.read_csv("model_search_results.csv")

# %%
df[df['model_type'] == 'classifier'].sort_values(['best_score'], ascending=False)
# Out:
#     log_return_lag  pred_next  model_type  best_score  feature_count  \
# 19               7          1  classifier    0.905929           1780
# 23               7          3  classifier    0.904086           1950
# 21               7          2  classifier    0.900821           1822
# 13               6          1  classifier    0.895987           1752
# 17               6          3  classifier    0.890167           1997
# 15               6          2  classifier    0.889019           1849
# 7                5          1  classifier    0.874805           1733
# 9                5          2  classifier    0.870382           1897
# 1                4          1  classifier    0.845617           1699
# 3                4          2  classifier    0.839087           1956
# 5                4          3  classifier    0.829490           2260
# 11               5          3  classifier    0.660581           2491
#
#               timestamp     status  duration_seconds  \
# 19  2025-10-27 14:37:07  completed       3393.235073
# 23  2025-10-27 18:33:18  completed       3588.389414
# 21  2025-10-27 16:36:40  completed       3596.962352
# 13  2025-10-27 08:54:20  completed       3283.337010
# 17  2025-10-27 12:38:48  completed       3523.738418
# 15  2025-10-27 10:45:02  completed       3287.673612
# 7   2025-10-27 03:28:05  completed       3374.053835
# 9   2025-10-27 05:14:20  completed       3232.074431
# 1   2025-10-26 21:43:49  completed       3019.495237
# 3   2025-10-26 23:41:38  completed       3820.880685
# 5   2025-10-27 01:34:58  completed       3469.092624
# 11  2025-10-27 07:02:19  completed       3274.470325
#
#                                           best_params  \
# 19  {"objective": "binary", "num_threads": -1, "ve...
# 23  {"objective": "binary", "num_threads": -1, "ve...
# 21  {"objective": "binary", "num_threads": -1, "ve...
# 13  {"objective": "binary", "num_threads": -1, "ve...
# 17  {"objective": "binary", "num_threads": -1, "ve...
# 15  {"objective": "binary", "num_threads": -1, "ve...
# 7   {"objective": "binary", "num_threads": -1, "ve...
# 9   {"objective": "binary", "num_threads": -1, "ve...
# 1   {"objective": "binary", "num_threads": -1, "ve...
# 3   {"objective": "binary", "num_threads": -1, "ve...
# 5   {"objective": "binary", "num_threads": -1, "ve...
# 11  {"objective": "binary", "num_threads": -1, "ve...
#
#                                     selected_features
# 19  ["cmma", "williams_r", "fisher_dt", "evenbette...
# 23  ["cmma", "fisher_dt", "williams_r", "trendflex...
# 21  ["cmma", "fisher_dt", "williams_r", "williams_...
# 13  ["cmma", "fisher_dt", "williams_r", "evenbette...
# 17  ["williams_r_norm20", "williams_r", "fisher_dt...
# 15  ["fisher_dt", "cmma", "williams_r", "trendflex...
# 7   ["fisher_dt", "williams_r", "cmma", "cwt_w32_1...
# 9   ["williams_r_norm20", "williams_r", "cmma", "f...
# 1   ["williams_r", "cmma", "fisher_dt", "frac_c_l3...
# 3   ["voss_0_dt", "williams_r_norm20", "williams_r...
# 5   ["bar_close_dt_norm20", "bar_close_dt_zscore20...
# 11  ["vwap", "ac_27_kurt20_lag5", "ma_difference",...

# %%
df[df['model_type'] == 'regressor'].sort_values(['best_score'], ascending=False)
# Out:
#     log_return_lag  pred_next model_type  best_score  feature_count  \
# 18               7          1  regressor    0.796254           3972
# 12               6          1  regressor    0.761739           3873
# 20               7          2  regressor    0.756637           4155
# 22               7          3  regressor    0.752842           1835
# 14               6          2  regressor    0.735186           1738
# 6                5          1  regressor    0.690543           3866
# 16               6          3  regressor    0.690401           1888
# 8                5          2  regressor    0.659000           1696
# 10               5          3  regressor    0.651755           1908
# 0                4          1  regressor    0.618419           3891
# 4                4          3  regressor    0.559829           2261
# 2                4          2  regressor    0.553139           1878
#
#               timestamp     status  duration_seconds  \
# 18  2025-10-27 13:40:33  completed       3705.600350
# 12  2025-10-27 07:59:37  completed       3438.276831
# 20  2025-10-27 15:36:43  completed       3576.484391
# 22  2025-10-27 17:33:29  completed       3409.162600
# 14  2025-10-27 09:50:15  completed       3354.567335
# 6   2025-10-27 02:31:51  completed       3412.846751
# 16  2025-10-27 11:40:04  completed       3301.461967
# 8   2025-10-27 04:20:28  completed       3142.627010
# 10  2025-10-27 06:07:44  completed       3204.355095
# 0   2025-10-26 20:53:30  completed       5947.623092
# 4   2025-10-27 00:37:09  completed       3330.910960
# 2   2025-10-26 22:37:57  completed       3247.921758
#
#                                           best_params  \
# 18  {"objective": "regression", "num_threads": -1,...
# 12  {"objective": "regression", "num_threads": -1,...
# 20  {"objective": "regression", "num_threads": -1,...
# 22  {"objective": "regression", "num_threads": -1,...
# 14  {"objective": "regression", "num_threads": -1,...
# 6   {"objective": "regression", "num_threads": -1,...
# 16  {"objective": "regression", "num_threads": -1,...
# 8   {"objective": "regression", "num_threads": -1,...
# 10  {"objective": "regression", "num_threads": -1,...
# 0   {"objective": "regression", "num_threads": -1,...
# 4   {"objective": "regression", "num_threads": -1,...
# 2   {"objective": "regression", "num_threads": -1,...
#
#                                     selected_features
# 18  ["cmma", "williams_r", "williams_r_norm20", "e...
# 12  ["cmma", "fisher_dt", "williams_r", "evenbette...
# 20  ["cmma", "fisher_dt", "williams_r", "williams_...
# 22  ["cmma", "fisher_dt", "williams_r", "trendflex...
# 14  ["cmma", "fisher_dt", "williams_r", "frac_c_l5...
# 6   ["cmma", "williams_r", "fisher_dt", "frac_c_l4...
# 16  ["williams_r_norm20", "cmma", "williams_r", "f...
# 8   ["williams_r", "cmma", "fisher_dt", "williams_...
# 10  ["voss_0_dt", "williams_r_norm20", "williams_r...
# 0   ["williams_r", "cmma", "fisher_dt", "frac_c_h3...
# 4   ["bar_close_dt_zscore20", "bar_close_dt_norm20...
# 2   ["voss_0_dt", "williams_r_norm20", "williams_r...
