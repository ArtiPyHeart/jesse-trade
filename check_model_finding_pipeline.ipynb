# %%
import pandas as pd

df = pd.read_csv("model_search_results.csv")
df.head()
# Out:
#    log_return_lag  pred_next  model_type  best_score  feature_count  \
# 0               4          1   regressor    0.532368           3720
# 1               4          1  classifier    0.832310           1659
# 2               4          2   regressor    0.476027           1821
# 3               4          2  classifier    0.806106            616
# 4               4          3   regressor    0.485995            764
#
#              timestamp     status  duration_seconds  \
# 0  2025-10-12 22:46:21  completed       3663.231430
# 1  2025-10-12 23:10:25  completed       1444.206895
# 2  2025-10-12 23:32:06  completed       1301.042142
# 3  2025-10-12 23:55:34  completed       1408.403791
# 4  2025-10-13 00:18:08  completed       1353.662277
#
#                                          best_params  \
# 0  {"objective": "regression", "num_threads": -1,...
# 1  {"objective": "binary", "num_threads": -1, "ve...
# 2  {"objective": "regression", "num_threads": -1,...
# 3  {"objective": "binary", "num_threads": -1, "ve...
# 4  {"objective": "regression", "num_threads": -1,...
#
#                                    selected_features
# 0  ["williams_r", "frac_c_h3_diff", "cmma", "fish...
# 1  ["williams_r", "fisher_dt", "cmma", "frac_c_h3...
# 2  ["williams_r", "corwin_schultz_estimator", "vo...
# 3  ["williams_r", "frac_c_h3_diff", "fisher_dt", ...
# 4  ["cmma_dt", "acc_swing_index_dt", "williams_r"...

# %%
df[df['model_type'] == 'classifier'].sort_values(['best_score'], ascending=False)
# Out:
#     log_return_lag  pred_next  model_type  best_score  feature_count  \
# 19               7          1  classifier    0.903695           1833
# 27               8          2  classifier    0.887366            698
# 13               6          1  classifier    0.887230           1807
# 17               6          3  classifier    0.880157            663
# 15               6          2  classifier    0.869491            557
# 21               7          2  classifier    0.866363           1891
# 7                5          1  classifier    0.863522           1688
# 9                5          2  classifier    0.852261            507
# 11               5          3  classifier    0.846287            699
# 5                4          3  classifier    0.838939            831
# 1                4          1  classifier    0.832310           1659
# 31               9          1  classifier    0.820735           4204
# 25               8          1  classifier    0.811223           1890
# 3                4          2  classifier    0.806106            616
# 29               8          3  classifier    0.753526           2083
# 23               7          3  classifier    0.609658           1135
# 33               9          2  classifier    0.603006           1124
# 35               9          3  classifier    0.583786           4772
#
#               timestamp     status  duration_seconds  \
# 19  2025-10-13 06:08:24  completed       1375.347901
# 27  2025-10-13 09:07:44  completed       1247.555370
# 13  2025-10-13 03:48:21  completed       1585.259834
# 17  2025-10-13 05:24:30  completed       1779.772287
# 15  2025-10-13 04:33:33  completed       1329.720915
# 21  2025-10-13 06:51:54  completed       1336.399478
# 7   2025-10-13 01:26:33  completed       1358.259484
# 9   2025-10-13 02:12:23  completed       1350.559779
# 11  2025-10-13 02:58:35  completed       1408.134503
# 5   2025-10-13 00:42:08  completed       1440.239555
# 1   2025-10-12 23:10:25  completed       1444.206895
# 31  2025-10-13 10:41:50  completed       1358.111498
# 25  2025-10-13 08:25:05  completed       1423.217191
# 3   2025-10-12 23:55:34  completed       1408.403791
# 29  2025-10-13 09:54:59  completed       1307.651837
# 23  2025-10-13 07:35:29  completed       1298.633662
# 33  2025-10-13 11:29:07  completed       1371.503954
# 35  2025-10-13 12:26:32  completed       1925.358750
#
#                                           best_params  \
# 19  {"objective": "binary", "num_threads": -1, "ve...
# 27  {"objective": "binary", "num_threads": -1, "ve...
# 13  {"objective": "binary", "num_threads": -1, "ve...
# 17  {"objective": "binary", "num_threads": -1, "ve...
# 15  {"objective": "binary", "num_threads": -1, "ve...
# 21  {"objective": "binary", "num_threads": -1, "ve...
# 7   {"objective": "binary", "num_threads": -1, "ve...
# 9   {"objective": "binary", "num_threads": -1, "ve...
# 11  {"objective": "binary", "num_threads": -1, "ve...
# 5   {"objective": "binary", "num_threads": -1, "ve...
# 1   {"objective": "binary", "num_threads": -1, "ve...
# 31  {"objective": "binary", "num_threads": -1, "ve...
# 25  {"objective": "binary", "num_threads": -1, "ve...
# 3   {"objective": "binary", "num_threads": -1, "ve...
# 29  {"objective": "binary", "num_threads": -1, "ve...
# 23  {"objective": "binary", "num_threads": -1, "ve...
# 33  {"objective": "binary", "num_threads": -1, "ve...
# 35  {"objective": "binary", "num_threads": -1, "ve...
#
#                                     selected_features
# 19  ["cmma", "williams_r", "fisher_dt", "swamichar...
# 27  ["williams_r", "cmma", "fisher_dt", "adx_7_dt"...
# 13  ["williams_r", "cmma", "fisher_dt", "evenbette...
# 17  ["fisher_dt", "williams_r", "frac_c_h3_diff", ...
# 15  ["williams_r", "fisher_dt", "cmma", "trendflex...
# 21  ["cmma", "williams_r", "fisher_dt", "trendflex...
# 7   ["fisher_dt", "williams_r", "cmma", "frac_c_h4...
# 9   ["williams_r", "frac_c_h3_diff", "fisher_dt", ...
# 11  ["williams_r", "frac_c_l3_diff", "frac_c_h3_di...
# 5   ["acc_swing_index_dt", "cmma_dt", "williams_r"...
# 1   ["williams_r", "fisher_dt", "cmma", "frac_c_h3...
# 31  ["cmma", "evenbetter_sinewave_short", "cmma_la...
# 25  ["cmma", "cmma_lag1", "evenbetter_sinewave_sho...
# 3   ["williams_r", "frac_c_h3_diff", "fisher_dt", ...
# 29  ["cmma", "voss_0", "fisher_dt", "cwt_w32_6", "...
# 23  ["cwt_w32_12_mean20", "ac_27_hurst20", "natr_l...
# 33  ["cwt_w64_20_lag5", "cwt_w64_18_lag2", "frac_l...
# 35  ["corwin_schultz_estimator_phent20", "cwt_w64_...

# %%
df[df['model_type'] == 'regressor'].sort_values(['best_score'], ascending=False)
# Out:
#     log_return_lag  pred_next model_type  best_score  feature_count  \
# 16               6          3  regressor    0.659932            575
# 6                5          1  regressor    0.657633           1498
# 14               6          2  regressor    0.623025           1718
# 8                5          2  regressor    0.557766           1673
# 10               5          3  regressor    0.550813           1847
# 0                4          1  regressor    0.532368           3720
# 30               9          1  regressor    0.514279           4029
# 24               8          1  regressor    0.498551           3987
# 4                4          3  regressor    0.485995            764
# 2                4          2  regressor    0.476027           1821
# 32               9          2  regressor    0.475138           4193
# 34               9          3  regressor    0.404709           4275
# 12               6          1  regressor    0.366055           4081
# 28               8          3  regressor    0.361535           4328
# 18               7          1  regressor    0.080528           1034
# 22               7          3  regressor    0.073892           2428
# 20               7          2  regressor    0.071136           1059
# 26               8          2  regressor    0.038211           1114
#
#               timestamp     status  duration_seconds  \
# 16  2025-10-13 04:54:50  completed       1276.607010
# 6   2025-10-13 01:03:55  completed       1306.373575
# 14  2025-10-13 04:11:24  completed       1382.777727
# 8   2025-10-13 01:49:52  completed       1399.169086
# 10  2025-10-13 02:35:07  completed       1364.428372
# 0   2025-10-12 22:46:21  completed       3663.231430
# 30  2025-10-13 10:19:12  completed       1453.049992
# 24  2025-10-13 08:01:22  completed       1553.093510
# 4   2025-10-13 00:18:08  completed       1353.662277
# 2   2025-10-12 23:32:06  completed       1301.042142
# 32  2025-10-13 11:06:16  completed       1465.875309
# 34  2025-10-13 11:54:27  completed       1519.495002
# 12  2025-10-13 03:21:56  completed       1400.240055
# 28  2025-10-13 09:33:11  completed       1527.273474
# 18  2025-10-13 05:45:28  completed       1258.612754
# 22  2025-10-13 07:13:50  completed       1316.374855
# 20  2025-10-13 06:29:38  completed       1273.904931
# 26  2025-10-13 08:46:56  completed       1310.728271
#
#                                           best_params  \
# 16  {"objective": "regression", "num_threads": -1,...
# 6   {"objective": "regression", "num_threads": -1,...
# 14  {"objective": "regression", "num_threads": -1,...
# 8   {"objective": "regression", "num_threads": -1,...
# 10  {"objective": "regression", "num_threads": -1,...
# 0   {"objective": "regression", "num_threads": -1,...
# 30  {"objective": "regression", "num_threads": -1,...
# 24  {"objective": "regression", "num_threads": -1,...
# 4   {"objective": "regression", "num_threads": -1,...
# 2   {"objective": "regression", "num_threads": -1,...
# 32  {"objective": "regression", "num_threads": -1,...
# 34  {"objective": "regression", "num_threads": -1,...
# 12  {"objective": "regression", "num_threads": -1,...
# 28  {"objective": "regression", "num_threads": -1,...
# 18  {"objective": "regression", "num_threads": -1,...
# 22  {"objective": "regression", "num_threads": -1,...
# 20  {"objective": "regression", "num_threads": -1,...
# 26  {"objective": "regression", "num_threads": -1,...
#
#                                     selected_features
# 16  ["williams_r", "cmma", "frac_c_h3_diff", "fish...
# 6   ["cmma", "fisher_dt", "williams_r", "frac_c_h4...
# 14  ["williams_r", "cmma", "fisher_dt", "trendflex...
# 8   ["williams_r", "frac_c_h3_diff", "cmma", "fish...
# 10  ["williams_r", "frac_c_l3_diff", "bekker_parki...
# 0   ["williams_r", "frac_c_h3_diff", "cmma", "fish...
# 30  ["cmma", "cmma_lag1", "evenbetter_sinewave_sho...
# 24  ["cmma", "cwt_w32_6_lag2", "cmma_lag1", "cwt_w...
# 4   ["cmma_dt", "acc_swing_index_dt", "williams_r"...
# 2   ["williams_r", "corwin_schultz_estimator", "vo...
# 32  ["cmma", "cwt_w32_6_lag2", "trendflex_ddt_lag5...
# 34  ["cmma", "voss_0", "cwt_w32_6_lag1", "williams...
# 12  ["cmma", "evenbetter_sinewave_short_dt", "fish...
# 28  ["cmma", "fisher_dt", "voss_0", "cwt_w32_6", "...
# 18  ["natr", "cwt_w32_2", "cwt_w32_14", "ac_27_hur...
# 22  ["cwt_w64_15", "bekker_parkinson_vol_curv20", ...
# 20  ["cwt_w32_12", "cwt_w64_15_lag1", "ac_27_hurst...
# 26  ["cwt_w32_10_lag5", "cwt_w64_20_lag5", "cwt_w6...
