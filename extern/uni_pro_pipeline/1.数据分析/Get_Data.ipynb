# %%
import rqdatac
rqdatac.init()
# Out:
# C:\Users\yohol\anaconda3\envs\new_world_3\lib\site-packages\rqdatac\client.py:245: UserWarning: Your account will be expired after  48 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "

# %%
data = rqdatac.get_price('RB99', start_date='2010-01-01', end_date='2025-01-31', frequency='1m')
data.to_csv('RB99_1m_2010.1.1_2025.1.31.csv')

# %%
data = rqdatac.get_price('IF99', start_date='2011-01-01', end_date='2025-01-31', frequency='1m')
data.to_csv('IF99_1m_2011.1.1_2025.1.31.csv')

# %%
data = rqdatac.get_price('FG99', start_date='2013-01-01', end_date='2025-01-31', frequency='1m')
data.to_csv('FG99_1m_2013.1.1_2025.1.31.csv')

# %%
data = rqdatac.get_price('RB99', start_date='2010-01-01', end_date='2025-01-31', frequency='30m')
data.to_csv('RB99_30m_2010.1.1_2025.1.31.csv')

# %%
data = rqdatac.get_price('RB99', start_date='2010-01-01', end_date='2025-01-31', frequency='120m')
data.to_csv('RB99_120m_2010.1.1_2025.1.31.csv')

# %%
data = rqdatac.get_price('IF99', start_date='2011-01-01', end_date='2025-01-31', frequency='30m')
data.to_csv('IF99_30m_2011.1.1_2025.1.31.csv')

# %%
data = rqdatac.get_price('IF99', start_date='2011-01-01', end_date='2025-01-31', frequency='120m')
data.to_csv('IF99_120m_2011.1.1_2025.1.31.csv')

# %%
data = rqdatac.get_price('FG99', start_date='2013-01-01', end_date='2025-01-31', frequency='30m')
data.to_csv('FG99_30m_2013.1.1_2025.1.31.csv')

# %%
data = rqdatac.get_price('FG99', start_date='2013-01-01', end_date='2025-01-31', frequency='120m')
data.to_csv('FG99_120m_2013.1.1_2025.1.31.csv')

# %%
AAA = rqdatac.get_price('510300.XSHG', start_date='2013-01-01', end_date='2025-01-31', frequency='1m')
AAA.to_csv('510300.XSHG_1m_2013.1.1_2025.1.31.csv')

# %%
AAA = rqdatac.get_price('510300.XSHG', start_date='2013-01-01', end_date='2025-01-31', frequency='30m')
AAA.to_csv('510300.XSHG_30m_2013.1.1_2025.1.31.csv')

# %%
AAA = rqdatac.get_price('510300.XSHG', start_date='2013-01-01', end_date='2025-01-31', frequency='120m')
AAA.to_csv('510300.XSHG_120m_2013.1.1_2025.1.31.csv')

# %%
AAA = rqdatac.get_price('512010.XSHG', start_date='2014-01-01', end_date='2025-01-31', frequency='1m')
AAA.to_csv('512010.XSHG_1m_2014.1.1_2025.1.31.csv')

# %%
AAA = rqdatac.get_price('512010.XSHG', start_date='2014-01-01', end_date='2025-01-31', frequency='30m')
AAA.to_csv('512010.XSHG_30m_2014.1.1_2025.1.31.csv')

# %%
AAA = rqdatac.get_price('512010.XSHG', start_date='2014-01-01', end_date='2025-01-31', frequency='120m')
AAA.to_csv('512010.XSHG_120m_2014.1.1_2025.1.31.csv')

# %%
data = rqdatac.get_price('M99', start_date='2010-01-01', end_date='2025-01-31', frequency='120m')
data.to_csv('M99_120m_2010.1.1_2025.1.31.csv')

# %%
data = rqdatac.get_price('M99', start_date='2010-01-01', end_date='2025-01-31', frequency='1m')
data.to_csv('M99_1m_2010.1.1_2025.1.31.csv')
