# %%
import rqdatac
rqdatac.init()

# %%
data = rqdatac.get_price('RB99', start_date='2010-01-01', end_date='2025-01-31', frequency='1m')
data.to_csv('RB99_1m_2010.1.1_2025.1.31.csv')

# %%
data = rqdatac.get_price('RB99', start_date='2019-01-01', end_date='2025-01-31', frequency='5m')
data.to_csv('RB99_5m_2019.1.1_2025.1.31.csv')

# %%
data = rqdatac.get_price('RB99', start_date='2019-01-01', end_date='2025-01-31', frequency='15m')
data.to_csv('RB99_15m_2019.1.1_2025.1.31.csv')

# %%
data = rqdatac.get_price('RB99', start_date='2019-01-01', end_date='2025-01-31', frequency='30m')
data.to_csv('RB99_30m_2019.1.1_2025.1.31.csv')

# %%
data = rqdatac.get_price('RB99', start_date='2019-01-01', end_date='2025-01-31', frequency='60m')
data.to_csv('RB99_60m_2019.1.1_2025.1.31.csv')

# %%
data = rqdatac.get_price('RB99', start_date='2019-01-01', end_date='2025-01-31', frequency='120m')
data.to_csv('RB99_120m_2019.1.1_2025.1.31.csv')

# %%
data = rqdatac.get_price('RB99', start_date='2010-01-01', end_date='2025-01-31', frequency='240m')
data.to_csv('RB99_240m_2010.1.1_2025.1.31.csv')

# %%
data = rqdatac.get_price('RB99', start_date='2019-01-01', end_date='2025-01-31', frequency='1d')
data.to_csv('RB99_1d_2019.1.1_2025.1.31.csv')

# %%
data = rqdatac.get_price('RB99', start_date='2019-01-01', end_date='2025-01-31', frequency='2d')
data.to_csv('RB99_2d_2019.1.1_2025.1.31.csv')

# %%
data = rqdatac.get_price('RB99', start_date='2019-01-01', end_date='2025-01-31', frequency='3d')
data.to_csv('RB99_3d_2019.1.1_2025.1.31.csv')

# %%
data = rqdatac.get_price('RB99', start_date='2019-01-01', end_date='2025-01-31', frequency='1w')
data.to_csv('RB99_1w_2019.1.1_2025.1.31.csv')
